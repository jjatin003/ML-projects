# %% [markdown]
# <a href="https://colab.research.google.com/github/jjatin003/ML-projects/blob/main/parkinsons_ML_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Upload the file

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b8a8d87c-44b8-4a46-af73-9f6869e1d701" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8a8d87c-44b8-4a46-af73-9f6869e1d701">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# For the prediction of best models for this dataset

# %%
from pycaret.classification import *
import pandas as pd
DataSet = pd.read_csv("parkinsons.csv")
##=DataSet.iloc[1::,1::]
s = setup(DataSet, target='status',normalize = True, normalize_method = 'robust',silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.9049  0.9762  1.0000  0.8963
# rf               Random Forest Classifier    0.9044  0.9524  0.9800  0.9090
# lightgbm  Light Gradient Boosting Machine    0.9044  0.9409  0.9509  0.9335
# gbc          Gradient Boosting Classifier    0.8973  0.9211  0.9600  0.9210
# knn                K Neighbors Classifier    0.8896  0.9352  0.9518  0.9148
# lda          Linear Discriminant Analysis    0.8681  0.8903  0.9909  0.8653
# ridge                    Ridge Classifier    0.8665  0.0000  0.9609  0.8861
# ada                  Ada Boost Classifier    0.8527  0.9000  0.9236  0.8990
# lr                    Logistic Regression    0.8451  0.9067  0.9236  0.8923
# dt               Decision Tree Classifier    0.8363  0.7639  0.8945  0.8970
# svm                   SVM - Linear Kernel    0.8291  0.0000  0.8936  0.8941
# ...

# %% [markdown]
# Top 5 rows of the dataset

# %%
DataSet.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %% [markdown]
# Bottom 5 rows of the dataset

# %%
DataSet.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %% [markdown]
# Number of rows and columns in the dataset

# %%
DataSet.shape
# Out:
# (195, 24)

# %% [markdown]
# More information about the dataset

# %%
DataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %% [markdown]
# Checking for missing values

# %%
DataSet.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# Distribution of target Variable/to check balanced or unbalanced dataset

# %%
DataSet['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %% [markdown]
# Separating the features & Target

# %%
X = DataSet.drop(columns=['name','status'], axis=1)
Y = DataSet['status']

# %%
print(X)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %% [markdown]
# Splitting the data to training data & Test data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %% [markdown]
# Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
model1 = LogisticRegression()
model2= SVC(kernel='linear')
model3 = RandomForestClassifier(max_depth=5, n_estimators=10)

##model1 = create_model('lr')

# %%
model1.fit(X_train, Y_train)
model2.fit(X_train, Y_train)
model3.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# Accuracy Results on model1 (Logistic Regression)

# %%
from sklearn.metrics import accuracy_score

# %%
X_train_prediction = model1.predict(X_train)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)
print('Accuracy score of training data : ', training_data_accuracy)
X_test_prediction = model1.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)
print('Accuracy score of test data : ', test_data_accuracy)
# Out:
# Accuracy score of training data :  0.8717948717948718
# Accuracy score of test data :  0.8461538461538461

# %% [markdown]
# Using cross validation

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
skfold= StratifiedKFold(n_splits=7)
scores = cross_val_score(model1, X, Y,cv=skfold)
print(max(scores))
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
x=[ "training_data_accuracy","test_data_accuracy","using_crossval"]
y=[training_data_accuracy,test_data_accuracy,max(scores)]
plt.plot(x,y)
plt.ylabel('Accuracy')
plt.title('Accuracy Results')
plt.show()

# %% [markdown]
# Accuracy results for model2 (SVM)

# %%
X_train_prediction = model2.predict(X_train)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)
print('Accuracy score of training data : ', training_data_accuracy)
X_test_prediction = model2.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)
print('Accuracy score of test data : ', test_data_accuracy)
# Out:
# Accuracy score of training data :  0.8653846153846154
# Accuracy score of test data :  0.8461538461538461

# %% [markdown]
# Using cross validation

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
skfold= StratifiedKFold(n_splits=7)
scores = cross_val_score(model2, X, Y,cv=skfold)
print(max(scores))
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
x=[ "training_data_accuracy","test_data_accuracy","using_crossval"]
y=[training_data_accuracy,test_data_accuracy,max(scores)]
plt.plot(x,y)
plt.ylabel('Accuracy')
plt.title('Accuracy Results')
plt.show()

# %% [markdown]
# Accuracy Results for model3 (Random Forest)

# %%
X_train_prediction = model3.predict(X_train)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)
print('Accuracy score of training data : ', training_data_accuracy)
X_test_prediction = model3.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)
print('Accuracy score of test data : ', test_data_accuracy)
# Out:
# Accuracy score of training data :  0.9871794871794872
# Accuracy score of test data :  0.9487179487179487

# %% [markdown]
# Using cross validation

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
skfold= StratifiedKFold(n_splits=7)
scores = cross_val_score(model3, X, Y,cv=skfold)
print(max(scores))
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
x=[ "training_data_accuracy","test_data_accuracy","using_crossval"]
y=[training_data_accuracy,test_data_accuracy,max(scores)]
plt.plot(x,y)
plt.ylabel('Accuracy')
plt.title('Accuracy Results')
plt.show()

# %% [markdown]
# Using SMOTE

# %%
# !pip install imblearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_res, y_train_res = sm.fit_resample(X_train, Y_train)

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(Y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(Y_train == 0)))
print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))
  
print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
# Out:
# Before OverSampling, counts of label '1': 118
# Before OverSampling, counts of label '0': 38
#
# After OverSampling, the shape of train_X: (236, 22)
# After OverSampling, the shape of train_y: (236,)
#
# After OverSampling, counts of label '1': 118
# After OverSampling, counts of label '0': 118

# %% [markdown]
# Logistic Regression

# %%
lr1 = LogisticRegression()
lr1.fit(X_train_res, y_train_res)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
X_train_prediction = lr1.predict(X_train_res)
training_data_accuracy = accuracy_score(y_train_res, X_train_prediction)
print('Accuracy score of training data : ', training_data_accuracy)
X_test_prediction = lr1.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)
print('Accuracy score of test data : ', test_data_accuracy)
# Out:
# Accuracy score of training data :  0.8389830508474576
# Accuracy score of test data :  0.7692307692307693

# %%
from sklearn.metrics import classification_report
predictions = lr1.predict(X_test)
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.80      0.64        10
#            1       0.92      0.76      0.83        29
#
#     accuracy                           0.77        39
#    macro avg       0.72      0.78      0.74        39
# weighted avg       0.82      0.77      0.78        39

# %% [markdown]
# without smote

# %%
predictions = model1.predict(X_test)
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67        10
#            1       0.87      0.93      0.90        29
#
#     accuracy                           0.85        39
#    macro avg       0.81      0.77      0.78        39
# weighted avg       0.84      0.85      0.84        39

# %% [markdown]
# SVM

# %%
svm2= SVC(kernel='linear')
svm2.fit(X_train_res, y_train_res)

X_train_prediction = svm2.predict(X_train_res)
training_data_accuracy = accuracy_score(y_train_res, X_train_prediction)
print('Accuracy score of training data : ', training_data_accuracy)
X_test_prediction = svm2.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)
print('Accuracy score of test data : ', test_data_accuracy)

predictions = svm2.predict(X_test)
print(classification_report(Y_test, predictions))
# Out:
# Accuracy score of training data :  0.8686440677966102
# Accuracy score of test data :  0.7948717948717948
#               precision    recall  f1-score   support
#
#            0       0.56      0.90      0.69        10
#            1       0.96      0.76      0.85        29
#
#     accuracy                           0.79        39
#    macro avg       0.76      0.83      0.77        39
# weighted avg       0.86      0.79      0.81        39

# %% [markdown]
# without somte

# %%
predictions = model2.predict(X_test)
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67        10
#            1       0.87      0.93      0.90        29
#
#     accuracy                           0.85        39
#    macro avg       0.81      0.77      0.78        39
# weighted avg       0.84      0.85      0.84        39

# %% [markdown]
# Random Forest

# %%
rf2=RandomForestClassifier()
rf2.fit(X_train_res, y_train_res)

X_train_prediction = rf2.predict(X_train_res)
training_data_accuracy = accuracy_score(y_train_res, X_train_prediction)
print('Accuracy score of training data : ', training_data_accuracy)
X_test_prediction = rf2.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)
print('Accuracy score of test data : ', test_data_accuracy)

predictions = rf2.predict(X_test)
print(classification_report(Y_test, predictions))
# Out:
# Accuracy score of training data :  1.0
# Accuracy score of test data :  1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        29
#
#     accuracy                           1.00        39
#    macro avg       1.00      1.00      1.00        39
# weighted avg       1.00      1.00      1.00        39

# %% [markdown]
# without smote

# %%
predictions = model3.predict(X_test)
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        10
#            1       0.97      0.97      0.97        29
#
#     accuracy                           0.95        39
#    macro avg       0.93      0.93      0.93        39
# weighted avg       0.95      0.95      0.95        39
